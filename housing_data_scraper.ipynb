# %%
from splinter import Browser
from bs4 import BeautifulSoup as bsoup
from urllib.request import urlopen
import requests
from splinter import Browser
import pandas as pd
import regex as re
import time

# %%
zips = [insert list of zips]

# %%
# max is 20
npages = 20

pages = []
price_all_data = []
address_all_data = []
stats_all_data = []
date_all_data = []

price_all_data.clear()
address_all_data.clear()
stats_all_data.clear()
date_all_data.clear()


for j in zips:
    ur = 'https://www.zillow.com/new-york-ny-'+str(j)

    for i in range(1, npages):
        url = ur+'/sold/'+str(i)+'_p/'
        pages.append(url)

        executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
        browser = Browser('chrome', **executable_path, headless=False)
        browser.visit(url)
        time.sleep(5)
        html = browser.html
        soup = bsoup(html, 'html.parser')

        price = soup.find_all('div', class_='list-card-price')

        address = soup.find_all(class_='list-card-addr')

        stats = soup.find_all(class_='list-card-details')

        date = soup.find_all(class_='list-card-variable-text list-card-img-overlay')

        for a in price:    
            price_all_data.append(a)
        for b in address:    
            address_all_data.append(b)
        for c in stats:
            stats_all_data.append(c)
        for d in date:
            date_all_data.append(d)

        price.clear()   
        address.clear()
        stats.clear()  
        date.clear()
        browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-189-f8dfcb4aa9b1> in <module>
#      25         browser.visit(url)
#      26         time.sleep(5)
# ---> 27         html = browser.html
#      28         soup = bsoup(html, 'html.parser')
#      29
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in html(self)
#     309     @property
#     310     def html(self):
# --> 311         return self.driver.page_source
#     312
#     313     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=86.0.4240.80)

# %%
len(price_all_data)
# Out:
# 43859

# %%
ab = str(price_all_data)
ac = ab.replace('<div class="list-card-price">$',"")
ad = ac.split('</div>,')
prices = pd.DataFrame(ad,columns=['price'])
# Out:
#                  price
# 0               [2.70M
# 1              990,000
# 2                1.67M
# 3                1.07M
# 4                1.21M
# ...                ...
# 43854            1.25M
# 43855          175,000
# 43856          530,000
# 43857          910,000
# 43858   179,000</div>]
#
# [43859 rows x 1 columns]

# %%
address_all_data
# Out:
# [<address class="list-card-addr">477 Sackett St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">60 E 8th St, New York, NY 10003</address>,
#  <address class="list-card-addr">28 Old Fulton St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">770 Washington Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">268 E Broadway #A1901, New York, NY 10002</address>,
#  <address class="list-card-addr">379 12th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">345 Montgomery St APT 5O, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">176 Sterling Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">149 Lafayette Ave APT 4B, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">385 Grand St APT L1204, New York, NY 10002</address>,
#  <address class="list-card-addr">446 3rd St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">806 Carroll St #4, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">185 Clinton Ave APT 3B, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">135 Willow St #801-2, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">1040 Carroll St APT 6D, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">679 Vanderbilt Ave APT 1-R, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">110 Clinton Ave APT 3A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">452 Lafayette Ave APT 5F, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">125 Ashland Pl APT 7A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">220 Broadway, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">15 Broad St APT 2430, New York, NY 10005</address>,
#  <address class="list-card-addr">330 S 3rd St APT 21, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">99 Battery Pl APT 14G, New York, NY 10280</address>,
#  <address class="list-card-addr">135 Eastern Parkway #APT, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">90 Beekman St APT 7A, New York, NY 10038</address>,
#  <address class="list-card-addr">514 9th St #4, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">85 Livingston St APT 11C, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">77-95 Livingston St #238, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">185 Park Row, New York, NY 10038</address>,
#  <address class="list-card-addr">417 Grand St APT D207, New York, NY 10002</address>,
#  <address class="list-card-addr">274 Saint Johns Pl APT 1B, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">323 2nd St APT 2R, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">168 Washington Ave #3, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">50 Clinton St #6C, New York, NY 10002</address>,
#  <address class="list-card-addr">195 Willoughby Ave, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">195 Willoughby Ave APT 611, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">279 Cumberland St APT 1, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">77 Bleecker St, New York, NY 10012</address>,
#  <address class="list-card-addr">111 S 3rd St #4C, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">323 E 8th St #1CG, New York, NY 10009</address>,
#  <address class="list-card-addr">55 Montgomery Pl, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">85 Livingston St APT 11C, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">1213 8th Ave APT 2, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">490 3rd St APT 3, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">445 Washington Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">189 Park Pl APT 2, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">185 Hall St, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">649 Vanderbilt Ave APT 3B, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">10 Little West St APT 16D, New York, NY 10004</address>,
#  <address class="list-card-addr">88 Bleecker St APT 2G, New York, NY 10012</address>,
#  <address class="list-card-addr">383 Grand St #M601, New York, NY 10002</address>,
#  <address class="list-card-addr">88 Bleecker St, New York, NY 10012</address>,
#  <address class="list-card-addr">357-389 Grand St, New York, NY 10002</address>,
#  <address class="list-card-addr">1206 Pacific St APT 1A, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">195 Willoughby Ave APT 1102, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">40 Prospect Park W APT 6H, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">530 Grand St, New York, NY 10002</address>,
#  <address class="list-card-addr">21 Powers St #1B, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">300 Rector Pl APT 1E, New York, NY 10280</address>,
#  <address class="list-card-addr">13 Downing ##9, New York, NY 10014</address>,
#  <address class="list-card-addr">1 Pierrepont St #2A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">415 E 12th St APT 3, New York, NY 10009</address>,
#  <address class="list-card-addr">88 Bleecker St APT 1A, New York, NY 10012</address>,
#  <address class="list-card-addr">34 N 7th St APT 3CC, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">541 1st St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">145 Nassau St #4E, New York, NY 10038</address>,
#  <address class="list-card-addr">16 Montgomery Pl #4, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">23 Waverly Pl APT 6E, New York, NY 10003</address>,
#  <address class="list-card-addr">160 Lincoln Pl APT 2B, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">378 Baltic St APT 10B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">120 2nd Ave, New York, NY 10003</address>,
#  <address class="list-card-addr">200 S 2nd St, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">21 Powers Street #3D, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">85 Stanton St, New York, NY 10002</address>,
#  <address class="list-card-addr">736 Dean St, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">805 Washington Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">185 18th St #702, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">48-54 Clove Rd, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">154 Lafayette Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">3 Hanover Sq APT 19E, New York, NY 10004</address>,
#  <address class="list-card-addr">3 Hanover Sq APT 19E, New York, NY 10004</address>,
#  <address class="list-card-addr">141 E 3rd St APT 10D, New York, NY 10009</address>,
#  <address class="list-card-addr">233 Pacific St APT 3D, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">130 Hicks St APT 4A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">155-167 Empire Blvd, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">89 State St APT 3, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">251 Pacific St APT 16, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">224 Monroe St, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">326 State St APT 1A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">225 Lincoln Pl APT 3J, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">333 Pearl St APT 17C, New York, NY 10038</address>,
#  <address class="list-card-addr">623 Lorimer St, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">25 Howard Pl, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">53 Boerum Pl APT 11B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">231 Park Pl APT 34, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">427 7th Ave APT 3, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">360 Clinton Ave APT 6-N, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">109 S 8th St #5, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">180 Park Row APT 21A, New York, NY 10007</address>,
#  <address class="list-card-addr">90 Gold St APT 19E, New York, NY 10038</address>,
#  <address class="list-card-addr">196-198 Park Row, New York, NY 10038</address>,
#  <address class="list-card-addr">160 Imlay St #3B4, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">180 5th Ave, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">197 Bridge St #11C, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">195 Willoughby Ave APT 513, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">810 Sterling Pl, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr
Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">66 N 1st St APT 2C, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">212 Forsyth St APT 58, New York, NY 10002</address>,
#  <address class="list-card-addr">429-435 Greenwich St #6A, New York, NY 10013</address>,
#  <address class="list-card-addr">377 Rector Pl APT 10F, New York, NY 10280</address>,
#  <address class="list-card-addr">120 2nd Ave APT 4C, New York, NY 10003</address>,
#  <address class="list-card-addr">66 N 1st St APT 2C, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">373 Classon Ave APT 1, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">147 Lafayette Ave #147B, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">122 Ashland Pl #183, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">75 Wall St APT 28P, New York, NY 10005</address>,
#  <address class="list-card-addr">122 Ashland Pl APT 3-H, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">184 Kent Ave APT B615, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">711 E 13th St, New York, NY 10009</address>,
#  <address class="list-card-addr">79 S 5th St #601, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">34-36 Underhill Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">369 Bergen St, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">345 Clinton Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">345 Clinton Ave APT 10D, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">660 Bergen St APT 1D, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">444 12th St APT 3B, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">8 Spruce St APT 60T, New York, NY 10038</address>,
#  <address class="list-card-addr">191 Willoughby St #83, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">673 Vanderbilt Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">58 Butler St APT 3, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">673 Vanderbilt Ave APT 3C, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">191 Willoughby St APT 3K, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">171 Lee Ave, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">145 Prospect Park W APT 2B, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">88 Bleecker St APT 3J, New York, NY 10012</address>,
#  <address class="list-card-addr">333 Rector Pl APT 411, New York, NY 10280</address>,
#  <address class="list-card-addr">85 Stanton St APT 3A, New York, NY 10002</address>,
#  <address class="list-card-addr">584 Leonard St, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">41 Saint Johns Pl #4, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">41 Saint Johns Pl #41D, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">815 8th Ave #8, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">175 Willoughby St #165, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">175 Willoughby St APT 9B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">777 Bedford Ave APT 1A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">151-155 Atlantic Ave APT 2A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">175 Willoughby St #183, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">815 8th Ave APT 1F, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">26 Park Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">777 Bedford Ave APT 1A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">385 Grand St APT L304, New York, NY 10002</address>,
#  <address class="list-card-addr">550 Grand St APT J3H, New York, NY 10002</address>,
#  <address class="list-card-addr">191 Spencer St APT 3A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">210 Clinton Ave APT 5B, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">378-382 Baltic St #9B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">35 Prospect Park W APT 12C, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">155 Newel St #4A, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">377 Rector Pl APT 8H, New York, NY 10280</address>,
#  <address class="list-card-addr">222-224 Park Pl #3C, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">809-811 Bedford Ave APT 5B, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">393 17th St APT 2B, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">31 Saint Felix St #4-C, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">195 Willoughby Ave APT 612, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">617 11th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">90 N 5th St APT 5C, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">84 Visitation Pl, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">25 Plaza St W APT 2E, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">550 Vanderbilt Ave APT 1410, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">315-317 16th St #3A, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">25 Plaza St W #73, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">684 Dean St, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">1 Hanson Pl APT 16A, Brooklyn, NY 11243</address>,
#  <address class="list-card-addr">Hamilton Ave, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">70 Grand St APT 5, New York, NY 10013</address>,
#  <address class="list-card-addr">64-70 Grand St, New York, NY 10013</address>,
#  <address class="list-card-addr">88 Greenwich St APT 2901, New York, NY 10006</address>,
#  <address class="list-card-addr">572 Grand St APT G804, New York, NY 10002</address>,
#  <address class="list-card-addr">35 Crown St #1A, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">18 N Portland Ave, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">374 Clermont Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">27-35 Crown St #58, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">739 E 14th St, New York, NY 10009</address>,
#  <address class="list-card-addr">157 Hudson St #2B, New York, NY 10013</address>,
#  <address class="list-card-addr">570 Grand St, New York, NY 10002</address>,
#  <address class="list-card-addr">904 Pacific St APT 201, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">1040 Carroll St APT 4G, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">1 Pulaski St, Brooklyn, NY 11206</address>,
#  <address class="list-card-addr">155 Newell St APT 1A, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">184 Prince St, New York, NY 10012</address>,
#  <address class="list-card-addr">25 Plaza St W APT 2E, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">224 22nd St APT 2C, Brooklyn, NY 11232</address>,
#  <address class="list-card-addr">475 7th Ave APT 1L, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">205 Clinton Ave #12E, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">355 Henry St #1, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">199 Saint Johns Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">325 Clinton Ave APT 2A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">196 Windsor Pl, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">62 Putnam Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">205 Water St APT 2A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">372 Clermont Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">85-101 N 3rd St #211, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">74 Richardson St #3, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">80 Elizabeth St APT 3G, New York, NY 10013</address>,
#  <address class="list-card-addr">184 Kent Ave APT C606, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">77 Bleecker St APT 829, New York, NY 10012</address>,
#  <address class="list-card-addr">45 Greene St APT 5, New York, NY 10013</address>,
#  <address class="list-card-addr">496 3rd St APT 2, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">90 Furman St #N1008, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">128 Willow St APT 3E, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">720 Sackett St, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">425 Prospect Pl, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">730 Bedford Ave APT 5B, Brooklyn, NY 11206</address>,
#  <address class="list-card-addr">425 Prospect Pl APT 2I, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">496 3rd St #5, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">130 Clinton St #89, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">150 Joralemon St APT 9G, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">175 Eastern Pkwy #78, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">50 Lefferts Ave APT 5F, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">50 Lefferts Ave #93, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">185 Hall St APT 811, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">175 Eastern Pkwy APT 2F, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">128 Willow St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">140 West St #13H, New York, NY 10007</address>,
#  <address class="list-card-addr">56 Pine St APT 15D, New York, NY 10005</address>,
#  <address class="list-card-addr">40 Broad St APT 23F, New York, NY 10004</address>,
#  <address class="list-card-addr">250 South St #34L, New York, NY 10002</address>,
#  <address class="list-card-addr">67 Liberty St APT 16, New York, NY 10005</address>,
#  <address class="list-card-addr">462 6th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">701 President St APT 4, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">227 Christopher Columbus Dr APT 437B, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">25 Hudson St #P7, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">121 Kingsland Ave #1B, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">366 6th St, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">268 Montgomery St, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">309 3rd St APT 5I, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">292 7th St APT D, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">330 Saint Marks Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">150 Skillman St APT 3, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">29 N Elliott Pl, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">560 Macdonough St, Brooklyn, NY 11233</address>,
#  <address class="list-card-addr">1600 Bergen St, Brooklyn, NY 11213</address>,
#  <address class="list-card-addr">219 Monitor St, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">34 N 7th St #2A, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">156 Conover St #2, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">366 2nd St, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">45 7th Ave APT 4, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">45 7th Ave APT 5, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">420 Lafayette Ave #A, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">118 Saint Marks Pl #3, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">87 3rd St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">137 Beadel St, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">30 Park Pl APT 39H, New York, NY 10007</address>,
#  <address class="list-card-addr">144 7th Ave, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">263 10th St APT 2D, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">186 Wayne St APT 416D, Jersey City, NJ 07302</address>,
#  <address class="list-card-addr">333 Grafton St, Brooklyn, NY 11212</address>,
#  <address class="list-card-addr">89 3rd St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">60 State St APT 2B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">420 12th St #70, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">420 12th St APT F3R, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">470 Quincy St, Brooklyn, NY 11221</address>,
#  <address class="list-card-addr">147 Lafayette Ave #B, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">145 President St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">423 Atlantic Ave APT 3B, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">279 1st St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">279 1st St APT 3A, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">423 Atlantic Ave #58, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">178 Court St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">147 Lafayette Ave #21, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">88 Greenwich St APT 1808, New York, NY 10006</address>,
#  <address class="list-card-addr">576 Wythe Ave APT 4A, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">308 N 7th St #2G, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">446 Clinton St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">339 Nostrand Ave, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">48 Sidney Pl, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">20 Pierrepont St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">59 Harrison Ave #1B, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">85 6th Ave APT G, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">660 4th Ave APT 3F, Brooklyn, NY 11232</address>,
#  <address class="list-card-addr">20 Pierrepont St APT 5A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">75 Broad St ROOM 2100, New York, NY 10004</address>,
#  <address class="list-card-addr">273 Rutledge St, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">308 N 7th St, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">112 Oak St, Brooklyn, NY 11222</address>,
#  <address class="list-card-addr">34 S 9th St APT 7B, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">2 S End Ave APT TH4, New York, NY 10280</address>,
#  <address class="list-card-addr">195 Adams St #8-F, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">798 President St #8, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">175 Adams St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">430 Sterling Pl #18, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">300 8th Ave APT 2J, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">970 Kent Ave APT 308, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">430 Sterling Pl APT 1A, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">550 Vanderbilt Ave APT 801, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">1015 President St, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">798 President St APT 3R, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">25 N Moore St APT 2C, New York, NY 10013</address>,
#  <address class="list-card-addr">385 Grand St APT L205, New York, NY 10002</address>,
#  <address class="list-card-addr">323 E 8th St APT 6B, New York, NY 10009</address>,
#  <address class="list-card-addr">235 Lincoln Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">689 Myrtle Ave APT 1D, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">185 Huntington St APT 5, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">235 Lincoln Pl APT 4B, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">79 Bridge St APT 6A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">415 Greenwich St PENTHOUSE B, New York, NY 10013</address>,
#  <address class="list-card-addr">30 Park Pl #40E, New York, NY 10007</address>,
#  <address class="list-card-addr">2 Northside Piers APT 27A, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">299 Pearl St APT 2A, New York, NY 10038</address>,
#  <address class="list-card-addr">21 Ludlow St APT 2C, New York, NY 10002</address>,
#  <address class="list-card-addr">30 Little West St #30B, New York, NY 10280</address>,
#  <address class="list-card-addr">185 Hall St APT 504, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">691-697 Washington Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">75 Henry St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">75 Henry St APT 17E, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">82 Beaver St PENTHOUSE 7, New York, NY 10005</address>,
#  <address class="list-card-addr">80 Warren St APT 66, New York, NY 10007</address>,
#  <address class="list-card-addr">385 Grand St APT L602, New York, NY 10002</address>,
#  <address class="list-card-addr">473 Franklin D Roosevelt Dr APT K101, New York, NY 10002</address>,
#  <address class="list-card-addr">77 Bleecker St #3067, New York, NY 10012</address>,
#  <address class="list-card-addr">184 Kent Ave APT A307, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">15 Broad St APT 2910, New York, NY 10005</address>,
#  <address class="list-card-addr">243 E 7th St, New York, NY 10009</address>,
#  <address class="list-card-addr">80-84 Warren St, New York, NY 10007</address>,
#  <address class="list-card-addr">101 Lafayette Ave APT 9M, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">554 4th Ave #6B, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">229 Flatbush Ave, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">376 Broadway APT 16D, New York, NY 10013</address>,
#  <address class="list-card-addr">74 Charlton St, New York, NY 10014</address>,
#  <address class="list-card-addr">162 Columbia Hts APT 1, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">224 22nd St, Brooklyn, NY 11232</address>,
#  <address class="list-card-addr">385 Grand St APT L602, New York, NY 10002</address>,
#  <address class="list-card-addr">102 3rd Pl, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">162 Columbia Hts APT 6, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">97 Quincy St, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">103 Lincoln Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">1035 President St, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">448 Court St APT 2R, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">55 Liberty St APT 28C, New York, NY 10005</address>,
#  <address class="list-card-addr">300 E 4th St, New York, NY 10009</address>,
#  <address class="list-card-addr">300 E 4th St APT 2D, New York, NY 10009</address>,
#  <address class="list-card-addr">53-55 Liberty Plz, New York, NY 10005</address>,
#  <address class="list-card-addr">1 Northside Piers APT 20J, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">20 Pierrepont St APT 5A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">356 Clinton Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">70 Clinton Ave, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">14 Lefferts Pl, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">96 Schermerhorn St APT 10B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">345 Montgomery St, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">96 Schermerhorn St APT 10B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">96 Schermerhorn St APT 10B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">345 Montgomery St APT 1E, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">345 Montgomery St, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">55 Wall St APT 614, New York, NY 10005</address>,
#  <address class="list-card-addr">303 E 8th St APT 4R, New York, NY 10009</address>,
#  <address class="list-card-addr">565 Broome St #N8E, New York, NY 10013</address>,
#  <address class="list-card-addr">112 Franklin St, New York, NY 10013</address>,
#  <address class="list-card-addr">303-305 E 8th St, New York, NY 10009</address>,
#  <address class="list-card-addr">34 N 7th St APT 2J, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">362 Clermont Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">62 Montague St #49, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">62 Montague St APT 5A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">361 Clinton Ave APT 2D, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">341 13th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">512 Classon Ave APT 4, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">75 Wall St APT 25J, New York, NY 10005</address>,
#  <address class="list-card-addr">500 4th Ave APT 2B, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">25 Bergen St APT 3A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">63 Pitt St, New York, NY 10002</address>,
#  <address class="list-card-addr">431 W Broadway #2, New York, NY 10012</address>,
#  <address class="list-card-addr">100 Beekman St APT 23A, New York, NY 10038</address>,
#  <address class="list-card-addr">80 Warren St APT 68, New York, NY 10007</address>,
#  <address class="list-card-addr">225 Rector Pl APT 2B, New York, NY 10280</address>,
#  <address class="list-card-addr">431 W Broadway, New York, NY 10012</address>,
#  <address class="list-card-addr">144 Rutledge St, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">7 4th Pl APT 4, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">755 Bergen St, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">205 Clinton St #4, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">79 Bridge St APT 4E, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">474 Prospect Ave, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">35 Crown St APT 2A, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">314 Hicks St, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">376 13th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">7 4th Pl APT 4, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">248 19th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">159 Garfield Pl APT 4R, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">800 Bedford Ave APT 1B, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">326 State St APT 3A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">334 E 5th St APT 2E, New York, NY 10003</address>,
#  <address class="list-card-addr">90 William St APT 2C, New York, NY 10038</address>,
#  <address class="list-card-addr">90 William St APT 2C, New York, NY 10038</address>,
#  <address class="list-card-addr">334 E 5th St, New York, NY 10003</address>,
#  <address class="list-card-addr">446 Kent Ave PENTHOUSE D, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">9-15 Murray St #8SE, New York, NY 10007</address>,
#  <address class="list-card-addr">227 E 7th St #2, New York, NY 10009</address>,
#  <address class="list-card-addr">267 Putnam Ave, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">163 6th Ave, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">185 Clinton Ave #520, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">296 Sterling Pl #23, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">306 Gold St APT 15C, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">110 Livingston St APT 3T, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">286 N 6th St #2861A, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">267 State St #A, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">99 John St APT 421, New York, NY 10038</address>,
#  <address class="list-card-addr">240-242 E Houston St #5E, New York, NY 10002</address>,
#  <address class="list-card-addr">181 Hudson St SUITE 2D, New York, NY 10013</address>,
#  <address class="list-card-addr">311 E 11th St #1A, New York, NY 10003</address>,
#  <address class="list-card-addr">176 Washington Park, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">365-101 Bridge St #11C, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">541 8th St #8, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">401 17th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">418-426 Saint Johns Pl #36, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">88 Wyckoff St APT L, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">426 9th St, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">115 S 8th St APT 12, Brooklyn, NY 11249</address>,
#  <address class="list-card-addr">30-46 3rd Ave, New York, NY 10003</address>,
#  <address class="list-card-addr">81 White St APT 6W, New York, NY 10013</address>,
#  <address class="list-card-addr">347 Bowery #R-9, New York, NY 10003</address>,
#  <address class="list-card-addr">374 S 2nd St APT 41, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">162-166 16th St #2A, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">335 5th Ave #2, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">96 Schermerhorn St APT 8E, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">110 Livingston St APT 4H, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">154 Underhill Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">71 Midwood St, Brooklyn, NY 11225</address>,
#  <address class="list-card-addr">99 John St APT 525, New York, NY 10038</address>,
#  <address class="list-card-addr">148 Chambers St APT 4, New York, NY 10007</address>,
#  <address class="list-card-addr">7 Harrison St #3S, New York, NY 10013</address>,
#  <address class="list-card-addr">55 Great Jones St, New York, NY 10012</address>,
#  <address class="list-card-addr">188 Adelphi St, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">289 Union St, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">486 Warren St, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">291 Union St #PS30, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">165 Clinton Ave APT 7J, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">399 Marcy Ave APT 3, Brooklyn, NY 11206</address>,
#  <address class="list-card-addr">333-347 4th St #60, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">152 Prospect Park W APT 9, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">15 Broad St APT 2600, New York, NY 10005</address>,
#  <address class="list-card-addr">15-23 Waverly Pl, New York, NY 10003</address>,
#  <address class="list-card-addr">403 Greenwich St #D, New York, NY 10013</address>,
#  <address class="list-card-addr">20 West St APT 15L, New York, NY 10004</address>,
#  <address class="list-card-addr">1 Tiffany Pl APT 4N, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">399 E 8th St #2A, New York, NY 10009</address>,
#  <address class="list-card-addr">298 Garfield Pl #8, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">225 S 3rd St APT 24, Brooklyn, NY 11211</address>,
#  <address class="list-card-addr">870 Pacific St APT 4R, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">215 Degraw St APT 3G, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr">425 3rd St APT 1, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">53 Boerum Pl APT 9F, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">111 6th Ave, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">462 Greenwich St APT 1, New York, NY 10013</address>,
#  <address class="list-card-addr">210 Lafayette St APT 7C, New York, NY 10012</address>,
#  <address class="list-card-addr">151-155 Atlantic Ave, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">431 Greene Ave, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">181 Clermont Ave APT 501, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">111 Hicks St APT 8G, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">186 Prospect Park W APT D2, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">210 Wallabout St APT 6B, Brooklyn, NY 11206</address>,
#  <address class="list-card-addr">251 Pacific St APT 21, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">245 Henry St APT 4I, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">60 Plaza St E #2D, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">420 12th St APT B3R, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">70 Little West St APT 10H, New York, NY 10004</address>,
#  <address class="list-card-addr">530 Grand St APT E10G, New York, NY 10002</address>,
#  <address class="list-card-addr">200 Chambers St APT 26E, New York, NY 10007</address>,
#  <address class="list-card-addr">50 Bayard St APT 2R, New York, NY 10013</address>,
#  <address class="list-card-addr">688 Broadway APT 7B, New York, NY 10012</address>,
#  <address class="list-card-addr">115 E 9th St APT 5P, New York, NY 10003</address>,
#  <address class="list-card-addr">196 Orchard St #5-L, New York, NY 10002</address>,
#  <address class="list-card-addr">185 Clinton Ave APT 15C, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">150 Rivington St APT 2H, New York, NY 10002</address>,
#  <address class="list-card-addr">202 W 9th St APT 1A, Brooklyn, NY 11231</address>,
#  <address class="list-card-addr
Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">510 Crown St APT 3D, Brooklyn, NY 11213</address>,
#  <address class="list-card-addr">191 Willoughby St APT 3K, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">673 Vanderbilt Ave APT 3C, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">673 Vanderbilt Ave, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">1131 Jefferson Ave, Brooklyn, NY 11221</address>,
#  <address class="list-card-addr">26 Park Pl, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">815 8th Ave APT 1F, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">175 Willoughby St #183, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">265 E 31st St, Brooklyn, NY 11226</address>,
#  <address class="list-card-addr">70 Lenox Rd APT F1, Brooklyn, NY 11226</address>,
#  <address class="list-card-addr">175 Willoughby St #165, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">41 Saint Johns Pl #41D, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">41 Saint Johns Pl #4, Brooklyn, NY 11217</address>,
#  <address class="list-card-addr">825 Gates Ave, Brooklyn, NY 11221</address>,
#  <address class="list-card-addr">221 Greene Ave #1, Brooklyn, NY 11238</address>,
#  <address class="list-card-addr">63 Lewis Ave #A, Brooklyn, NY 11206</address>,
#  <address class="list-card-addr">815 8th Ave #8, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">505 Monroe St, Brooklyn, NY 11221</address>,
#  <address class="list-card-addr">175 Willoughby St APT 9B, Brooklyn, NY 11201</address>,
#  <address class="list-card-addr">777 Bedford Ave APT 1A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">16 E 58th St, Brooklyn, NY 11203</address>,
#  <address class="list-card-addr">70 Lenox Rd #60, Brooklyn, NY 11226</address>,
#  <address class="list-card-addr">550 Grand St APT J3H, New York, NY 10002</address>,
#  <address class="list-card-addr">35 Prospect Park W APT 12C, Brooklyn, NY 11215</address>,
#  <address class="list-card-addr">191 Spencer St APT 3A, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">485-487 Tompkins Ave, Brooklyn, NY 11216</address>,
#  <address class="list-card-addr">210 Clinton Ave APT 5B, Brooklyn, NY 11205</address>,
#  <address class="list-card-addr">35 Clarkson Ave APT 4C, Brooklyn, NY 11226</address>,
#  <address class="list-card-addr">808-810 Rogers Ave, Brooklyn, NY 11226</address>,
#  <address class="list-card-addr">1009 Hancock St #4, Brooklyn, NY 11221</address>,
#  <address class="list-card-addr">310 Beverly Rd #2J, Brooklyn, NY 11218</address>,
#  ...]

# %%
y = str(address_all_data)
z = y.split(">")
t = pd.DataFrame(z,columns=['address'])
s = t[t != ', <address class="list-card-addr"']
r = s[s != ']']
df3 = r[r.index % 2 == 1]
df4 = df3.reset_index(drop=True)
df4
# Out:
#                                                  address
# 0            477 Sackett St, Brooklyn, NY 11231</address
# 1               60 E 8th St, New York, NY 10003</address
# 2          28 Old Fulton St, Brooklyn, NY 11201</address
# 3        770 Washington Ave, Brooklyn, NY 11238</address
# 4      268 E Broadway #A1901, New York, NY 10002</add...
# ...                                                  ...
# 43854    8703 Chevy Chase St, Jamaica, NY 11432</address
# 43855  16420 Highland Ave APT 2U, Jamaica, NY 11432</...
# 43856          8133 164th Pl, Jamaica, NY 11432</address
# 43857          8714 168th St, Jamaica, NY 11432</address
# 43858  160-10 89th Ave APT 12E, Jamaica, NY 11432</ad...
#
# [43859 rows x 1 columns]

# %%
yy = pd.DataFrame(stats_all_data)
zz = yy.replace('\d',"")
zz
# Out:
#                                                        0
# 0      [[5, [ ,  , bds]], [5, [ ,  , ba]], [2,100, [ ...
# 1      [[2, [ ,  , bds]], [2, [ ,  , ba]], [445,151, ...
# 2      [[2, [ ,  , bds]], [2, [ ,  , ba]], [2,100, [ ...
# 3      [[1, [ ,  , bd]], [1, [ ,  , ba]], [850, [ ,  ...
# 4      [[--, [ ,  , bds]], [--, [ ,  , ba]], [--, [ ,...
# ...                                                  ...
# 43854  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,500, [ ...
# 43855  [[1, [ ,  , bd]], [1, [ ,  , ba]], [--, [ ,  ,...
# 43856  [[5, [ ,  , bds]], [2, [ ,  , ba]], [2,000, [ ...
# 43857  [[5, [ ,  , bds]], [5, [ ,  , ba]], [3,100, [ ...
# 43858  [[2, [ ,  , bds]], [1, [ ,  , ba]], [1,000, [ ...
#
# [43859 rows x 1 columns]

# %%
c = str(date_all_data)
d = c.split(">")
e = pd.DataFrame(d,columns=['Sold Date'])
f = e[e != ', <address class="list-card-addr"']
y = f[f != ']']
df3 = y[y.index % 2 == 1]
df3 = df3.reset_index(drop=True)
df3
# Out:
#                   Sold Date
# 0      Sold 10/15/2020</div
# 1      Sold 10/15/2020</div
# 2      Sold 10/14/2020</div
# 3      Sold 10/14/2020</div
# 4      Sold 10/14/2020</div
# ...                     ...
# 43854  Sold 08/03/2018</div
# 43855  Sold 08/02/2018</div
# 43856  Sold 08/02/2018</div
# 43857  Sold 08/01/2018</div
# 43858  Sold 07/31/2018</div
#
# [43859 rows x 1 columns]

# %%
final1 = pd.concat([df4, df3.reindex(df4.index)], axis=1)
final2 = pd.concat([final1, zz.reindex(final1.index)], axis=1)
final3 = pd.concat([final2, prices.reindex(final2.index)], axis=1)
final3
# Out:
#                                                  address  \
# 0            477 Sackett St, Brooklyn, NY 11231</address
# 1               60 E 8th St, New York, NY 10003</address
# 2          28 Old Fulton St, Brooklyn, NY 11201</address
# 3        770 Washington Ave, Brooklyn, NY 11238</address
# 4      268 E Broadway #A1901, New York, NY 10002</add...
# ...                                                  ...
# 43854    8703 Chevy Chase St, Jamaica, NY 11432</address
# 43855  16420 Highland Ave APT 2U, Jamaica, NY 11432</...
# 43856          8133 164th Pl, Jamaica, NY 11432</address
# 43857          8714 168th St, Jamaica, NY 11432</address
# 43858  160-10 89th Ave APT 12E, Jamaica, NY 11432</ad...
#
#                   Sold Date  \
# 0      Sold 10/15/2020</div
# 1      Sold 10/15/2020</div
# 2      Sold 10/14/2020</div
# 3      Sold 10/14/2020</div
# 4      Sold 10/14/2020</div
# ...                     ...
# 43854  Sold 08/03/2018</div
# 43855  Sold 08/02/2018</div
# 43856  Sold 08/02/2018</div
# 43857  Sold 08/01/2018</div
# 43858  Sold 07/31/2018</div
#
#                                                        0            price
# 0      [[5, [ ,  , bds]], [5, [ ,  , ba]], [2,100, [ ...           [2.70M
# 1      [[2, [ ,  , bds]], [2, [ ,  , ba]], [445,151, ...          990,000
# 2      [[2, [ ,  , bds]], [2, [ ,  , ba]], [2,100, [ ...            1.67M
# 3      [[1, [ ,  , bd]], [1, [ ,  , ba]], [850, [ ,  ...            1.07M
# 4      [[--, [ ,  , bds]], [--, [ ,  , ba]], [--, [ ,...            1.21M
# ...                                                  ...              ...
# 43854  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,500, [ ...            1.25M
# 43855  [[1, [ ,  , bd]], [1, [ ,  , ba]], [--, [ ,  ,...          175,000
# 43856  [[5, [ ,  , bds]], [2, [ ,  , ba]], [2,000, [ ...          530,000
# 43857  [[5, [ ,  , bds]], [5, [ ,  , ba]], [3,100, [ ...          910,000
# 43858  [[2, [ ,  , bds]], [1, [ ,  , ba]], [1,000, [ ...   179,000</div>]
#
# [43859 rows x 4 columns]

# %%
final3.to_csv('house3.csv')
